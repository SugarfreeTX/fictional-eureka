# %%
import pandas as pd

# %%
budget_df = pd.DataFrame(
    {
        "Date Due": ["2023-01-01", "2023-01-02", "2026-04-24", "2026-04-24", "2026-04-25", "2026-04-25", "2026-04-25"], 
        "Amount Due": [0, 0, 2386.03, 2034.92, 2657.99, 2034.92+2657.99, 4692.91-2386.03], 
        "Category": ["Strata", "Double Cash Back", "Apple", "Deposit", "C.Balance", "T.Balance", "R.Balance"] 
    }
)

# %%
budget_df.head(10)
# Out:
#      Date Due  Amount Due          Category
# 0  2023-01-01        0.00            Strata
# 1  2023-01-02        0.00  Double Cash Back
# 2  2026-04-24     2386.03             Apple
# 3  2026-04-24     2034.92           Deposit
# 4  2026-04-25     2657.99         C.Balance
# 5  2026-04-25     4692.91         T.Balance
# 6  2026-04-25     2306.88         R.Balance

# %% [markdown]
# ### **Savings Balance**

# %%
# Current Savings 2026-04-16: 3127.95 

# 2026-04-24: 
3127.95 + 1600 # Savings + IRS deposit
# Out:
# 4727.95

# %% [markdown]
# ### **May 2026**

# %%
# 2026-05-08: 2034.92
print("Balance on 2026-05-08:", 2034.92 + 2306.88)
# Out:
# Balance on 2026-05-08: 4341.8

# %%
# Due 2026-05-10: Citi Cards

print("Total Due Citi Cards:", 1765.93 + 1900.66)
# Out:
# Total Due Citi Cards: 3666.59

# %%
# 2026-05-08: 
print("Remaining balance after 2026-05-08:", 4341.80 - 3666.59)
# Out:
# Remaining balance after 2026-05-08: 675.21

# %% [markdown]
# ### **End of May 2026**

# %%
# 2026-05-22: 2034.92
print("Balance on 2026-05-22:", 2034.92 + 675.21) # Deposits + R.Balance
# Out:
# Balance on 2026-05-22: 2710.13
